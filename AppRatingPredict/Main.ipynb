# %% [markdown]
# Тут я попробую написать модель для предсказания рейтинга приложения в зависимости от его х-к

# %% [markdown]
# ### sklearn
# В sklearn есть два типа объектов:
#
# 1. Estimator -- модель для предсказаний. Есть метод .fit(X, y) и .predict(X)
# 2. Transformer -- обработчик данных (например нормирование признаков). Есть метод .fit(X) и .transform(X)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./AppleStore.csv')
data.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %% [markdown]
# Оставим только те столбцы что нам нужны

# %%
num_cols = [
    'size_bytes',
    'price',
    'rating_count_tot',
    'rating_count_ver',
    'sup_devices.num',
    'ipadSc_urls.num',
    'lang.num',
    'cont_rating',
]

cat_cols = [
    'currency',
    'prime_genre'
]

target_col = 'user_rating'

cols = num_cols + cat_cols + [target_col]

# %%
data = data[cols]
data.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0   100788224   3.99             21292                26               38
# 1   158578688   0.00            161065                26               37
# 2   100524032   0.00            188583              2822               37
# 3   128512000   0.00            262241               649               37
# 4    92774400   0.00            985920              5320               37
#
#    ipadSc_urls.num  lang.num cont_rating currency   prime_genre  user_rating
# 0                5        10          4+      USD         Games          4.0
# 1                5        23          4+      USD  Productivity          4.0
# 2                5         3          4+      USD       Weather          3.5
# 3                5         9         12+      USD      Shopping          4.0
# 4                5        45          4+      USD     Reference          4.5

# %% [markdown]
# Ну для начала нужно убрать "+" из возрастного ограничения

# %%
data['cont_rating'] = data['cont_rating'].str[0:-1].astype(int)
data.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0   100788224   3.99             21292                26               38
# 1   158578688   0.00            161065                26               37
# 2   100524032   0.00            188583              2822               37
# 3   128512000   0.00            262241               649               37
# 4    92774400   0.00            985920              5320               37
#
#    ipadSc_urls.num  lang.num  cont_rating currency   prime_genre  user_rating
# 0                5        10            4      USD         Games          4.0
# 1                5        23            4      USD  Productivity          4.0
# 2                5         3            4      USD       Weather          3.5
# 3                5         9           12      USD      Shopping          4.0
# 4                5        45            4      USD     Reference          4.5

# %% [markdown]
# Теперь нужно проверить есть ли пустые значение,
# вот отличный способ
#
# isna() возвращает матрицу со значением False где есть данные и True там где их нет

# %%
data.isna()
# Out:
#       size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0          False  False             False             False            False
# 1          False  False             False             False            False
# 2          False  False             False             False            False
# 3          False  False             False             False            False
# 4          False  False             False             False            False
# ...          ...    ...               ...               ...              ...
# 7192       False  False             False             False            False
# 7193       False  False             False             False            False
# 7194       False  False             False             False            False
# 7195       False  False             False             False            False
# 7196       False  False             False             False            False
#
#       ipadSc_urls.num  lang.num  cont_rating  currency  prime_genre  \
# 0               False     False        False     False        False
# 1               False     False        False     False        False
# 2               False     False        False     False        False
# 3               False     False        False     False        False
# 4               False     False        False     False        False
# ...               ...       ...          ...       ...          ...
# 7192            False     False        False     False        False
# 7193            False     False        False     False        False
# 7194            False     False        False     False        False
# 7195            False     False        False     False        False
# 7196            False     False        False     False        False
#
#       user_rating
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 7192        False
# 7193        False
# 7194        False
# 7195        False
# 7196        False
#
# [7197 rows x 11 columns]

# %%
data.isna().mean()
# Out:
# size_bytes          0.0
# price               0.0
# rating_count_tot    0.0
# rating_count_ver    0.0
# sup_devices.num     0.0
# ipadSc_urls.num     0.0
# lang.num            0.0
# cont_rating         0.0
# currency            0.0
# prime_genre         0.0
# user_rating         0.0
# dtype: float64

# %% [markdown]
# Посмотрим какие категориальные данные у нас есть

# %%
for cat in cat_cols:
    print(cat)
    print(data[cat].value_counts())
    print()
# Out:
# currency
# USD    7197
# Name: currency, dtype: int64
#
# prime_genre
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: prime_genre, dtype: int64

# %% [markdown]
# Как видно валюта (currency) одинаковая везде, следовательно от нее можно и избавиться

# %%
data = data.drop(columns='currency')
cat_cols.remove('currency')
data.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0   100788224   3.99             21292                26               38
# 1   158578688   0.00            161065                26               37
# 2   100524032   0.00            188583              2822               37
# 3   128512000   0.00            262241               649               37
# 4    92774400   0.00            985920              5320               37
#
#    ipadSc_urls.num  lang.num  cont_rating   prime_genre  user_rating
# 0                5        10            4         Games          4.0
# 1                5        23            4  Productivity          4.0
# 2                5         3            4       Weather          3.5
# 3                5         9           12      Shopping          4.0
# 4                5        45            4     Reference          4.5

# %% [markdown]
# Тут можно посмотреть кореляцию
# Как видно больше всего значение user_rating а я напомню это именно то что я хочу предсказывать зависит от ipadSc_urls.num, хз что это :))
#
# Надеюсь, Илюха, ты не забыл что такое кореляция

# %%
data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col0,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col1,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col2,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col3,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col4,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col5,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col6,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col7,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col1,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col0{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col2,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col3{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col3,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col6{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col4,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col2,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col3,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col4,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col0,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col1,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col7,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col5,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col6,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col5{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col6,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col1,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col4,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col4{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col7,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col6{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow0_col8,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col8{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col6{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col7,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col4{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow1_col8{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col0,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col5,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col0,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col0{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col3,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col5{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col4,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col7{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col6,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col2{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col7{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow2_col8,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col0{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col1{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col4{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col5,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col2{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col6,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col1{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow3_col7{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col2,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col2{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col3{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col5{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow4_col8{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col0,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col8{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col1{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col2{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col6,#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col1{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow5_col8{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col1{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col2{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col3{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow6_col7{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col0{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col3{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow7_col4{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col3{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col5{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_5bea2c34_82a3_11eb_b34a_e1677e49508frow8_col7{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }</style><table id="T_5bea2c34_82a3_11eb_b34a_e1677e49508f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >size_bytes</th>        <th class="col_heading level0 col1" >price</th>        <th class="col_heading level0 col2" >rating_count_tot</th>        <th class="col_heading level0 col3" >rating_count_ver</th>        <th class="col_heading level0 col4" >sup_devices.num</th>        <th class="col_heading level0 col5" >ipadSc_urls.num</th>        <th class="col_heading level0 col6" >lang.num</th>        <th class="col_heading level0 col7" >cont_rating</t

# %% [markdown]
# Теперь нужно избавиться от категориальных колонок

# %%
data = pd.get_dummies(data, columns=cat_cols)
data.head()
# Out:
#    size_bytes  price  rating_count_tot  rating_count_ver  sup_devices.num  \
# 0   100788224   3.99             21292                26               38
# 1   158578688   0.00            161065                26               37
# 2   100524032   0.00            188583              2822               37
# 3   128512000   0.00            262241               649               37
# 4    92774400   0.00            985920              5320               37
#
#    ipadSc_urls.num  lang.num  cont_rating  user_rating  prime_genre_Book  ...  \
# 0                5        10            4          4.0                 0  ...
# 1                5        23            4          4.0                 0  ...
# 2                5         3            4          3.5                 0  ...
# 3                5         9           12          4.0                 0  ...
# 4                5        45            4          4.5                 0  ...
#
#    prime_genre_News  prime_genre_Photo & Video  prime_genre_Productivity  \
# 0                 0                          0                         0
# 1                 0                          0                         1
# 2                 0                          0                         0
# 3                 0                          0                         0
# 4                 0                          0                         0
#
#    prime_genre_Reference  prime_genre_Shopping  prime_genre_Social Networking  \
# 0                      0                     0                              0
# 1                      0                     0                              0
# 2                      0                     0                              0
# 3                      0                     1                              0
# 4                      1                     0                              0
#
#    prime_genre_Sports  prime_genre_Travel  prime_genre_Utilities  \
# 0                   0                   0                      0
# 1                   0                   0                      0
# 2                   0                   0                      0
# 3                   0                   0                      0
# 4                   0                   0                      0
#
#    prime_genre_Weather
# 0                    0
# 1                    0
# 2                    1
# 3                    0
# 4                    0
#
# [5 rows x 32 columns]

# %%
new_cat_cols = []
for cat_name in cat_cols:
    new_cat_cols.extend([new_cat_name for new_cat_name in data.columns if new_cat_name.startswith(cat_name)])
    
cat_cols = new_cat_cols

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(data[num_cols + cat_cols])

X = scaler.transform(data[num_cols + cat_cols])

# %% [markdown]
# ## Разделение на train/test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, data['user_rating'], test_size=0.2)

# %% [markdown]
# ## Обучение

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
def print_metrics(y_pred, y):
    print(f'R^2 - {r2_score(y_pred, y)}')
    print(f'mean_squared - {mean_squared_error(y_pred, y)}')

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

print_metrics(lr.predict(X_test), y_test)
# Out:
# R^2 - -5.84859029797293
# mean_squared - 1.9900297652123407

# %%
kn = KNeighborsRegressor()
kn.fit(X_train, y_train)

print_metrics(kn.predict(X_test), y_test)
# Out:
# R^2 - -0.8488914837005206
# mean_squared - 1.968020833333333
